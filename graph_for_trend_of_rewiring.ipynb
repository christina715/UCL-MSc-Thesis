# %%
import networkx as nx
from operator import itemgetter
from networkx import ego_graph
import matplotlib.pyplot as plt
import pylab 
import random
import pandas as pd
from networkx.algorithms.assortativity.mixing import mixing_dict
from networkx.utils import dict_to_numpy_array
from networkx.utils import accumulate
import scipy.stats as stats
import numpy as np  
#import pylab as pl
from pylab import *  
from matplotlib.ticker import MultipleLocator, FormatStrFormatter
import pandas as pd
import sys, os
import random

# %%
ASS_BA = pd.read_csv('BA/trend_assortative_BA.csv',header=None)
ASS_ER = pd.read_csv('ER/trend_assortative_ER.csv',header=None)
ASS_PROTEIN = pd.read_csv('protein/trend_assortative_protein.csv',header=None)
ASS_SCIENTIST = pd.read_csv('scientist/trend_assortative_scientist.csv',header=None)
ASS_INTERNET = pd.read_csv('internet/trend_assortative_internet.csv',header=None)



DIS_BA = pd.read_csv('BA/trend_disassortative_BA.csv',header=None)
DIS_ER = pd.read_csv('ER/trend_disassortative_ER.csv',header=None)
DIS_PROTEIN = pd.read_csv('protein/trend_disassortative_protein.csv',header=None)
DIS_SCIENTIST = pd.read_csv('scientist/trend_disassortative_scientist.csv',header=None)
DIS_INTERNET = pd.read_csv('internet/trend_disassortative_internet.csv',header=None)

# %%
fig = plt.figure(figsize=(5, 3))
ax = fig.add_subplot(111)
#ax.set_aspect(1)
#ax.set_xlim(0, 1400)
index1=np.arange(0, len(ASS_BA)*1000, 1000)
index2=np.arange(0, len(ASS_ER)*1000, 1000)
index3=np.arange(0, len(ASS_PROTEIN)*1000, 1000)
index4=np.arange(0, len(ASS_SCIENTIST)*1000, 1000)
index5=np.arange(0, len(ASS_INTERNET)*1000, 1000)


ax.plot(index1,ASS_BA,'co:',label='BA')
ax.plot(index2,ASS_ER,'mx--',label='ER')
ax.plot(index3,ASS_PROTEIN,'yp-.',label='Protein')
ax.plot(index4,ASS_SCIENTIST,'g*--',label='Scientist')
pylab.legend(loc='lower right')

plt.show()

# %%
fig = plt.figure(figsize=(5, 3))
ax = fig.add_subplot(111)
#ax.set_aspect(1)
#ax.set_xlim(0, 1400)

ax.plot(ASS_BA,'c',label='BA')
ax.plot(ASS_ER,'m',label='ER')
ax.plot(ASS_PROTEIN,'y',label='Protein')
ax.plot(ASS_SCIENTIST,'g',label='Scientist')
ax.plot(ASS_INTERNET,'R',label='Internet')

pylab.legend(loc='lower right')

plt.savefig('trend_assortative.png')
plt.show()

# %%
fig = plt.figure(figsize=(5, 3))
ax = fig.add_subplot(111)
#ax.set_aspect(1)

ax.plot(DIS_BA,'c',label='BA')
ax.plot(DIS_ER,'m',label='ER')
ax.plot(DIS_PROTEIN,'y',label='Protein')
ax.plot(DIS_SCIENTIST,'g',label='Scientist')
ax.plot(DIS_INTERNET,'R',label='Internet')


pylab.legend(loc='upper right')

plt.savefig('trend_disasso.png')

plt.show()

# %%
random_BA_1 = pd.read_csv('BA/random_BA_1.csv',header=None)
random_BA_2 = pd.read_csv('BA/random_BA_2.csv',header=None)
random_BA_3 = pd.read_csv('BA/random_BA_3.csv',header=None)
random_BA_4 = pd.read_csv('BA/random_BA_4.csv',header=None)
random_BA_5 = pd.read_csv('BA/random_BA_5.csv',header=None)
random_BA_6 = pd.read_csv('BA/random_BA_6.csv',header=None)
random_BA_7 = pd.read_csv('BA/random_BA_7.csv',header=None)
random_BA_8 = pd.read_csv('BA/random_BA_8.csv',header=None)
random_BA_9 = pd.read_csv('BA/random_BA_9.csv',header=None)
random_BA_10 = pd.read_csv('BA/random_BA_10.csv',header=None)

# %%
fig = plt.figure(figsize=(10, 4))

bx = fig.add_subplot(111)
#ax.set_aspect(1)
bx.set_ylim(-0.2, 0.2)

#ax.set_aspect(1)
bx.set_ylim(-0.2, 0.2)
bx.plot(random_BA_1,'b',label='Random_1')
bx.plot(random_BA_2,'c',label='Random_2')
bx.plot(random_BA_3,'g',label='Random_3')
bx.plot(random_BA_4,'k',label='Random_4')
bx.plot(random_BA_5,'m',label='Random_5')
bx.plot(random_BA_6,'r',label='Random_6')
bx.plot(random_BA_7,'w',label='Random_7')
bx.plot(random_BA_8,'y',label='Random_8')
bx.plot(random_BA_9,'#F0F8FF',label='Random_9')
bx.plot(random_BA_10,'#FFF8DC',label='Random_10')

plt.title('BA', fontsize = 10)


plt.xlabel('rewiring times',fontsize=12)
plt.ylabel('Second-order assortative coefficient',fontsize=10)
plt.savefig('trend_BA.png')


plt.show()

# %%
fig = plt.figure(figsize=(10, 4))

ax = fig.add_subplot(111)
#ax.set_aspect(1)
ax.set_ylim(-0.2, 0.2)


ax.plot(random_ER_1,'b',label='Random_1')
ax.plot(random_ER_2,'c',label='Random_2')
ax.plot(random_ER_3,'g',label='Random_3')
ax.plot(random_ER_4,'k',label='Random_4')
ax.plot(random_ER_5,'m',label='Random_5')
ax.plot(random_ER_6,'r',label='Random_6')
ax.plot(random_ER_7,'w',label='Random_7')
ax.plot(random_ER_8,'y',label='Random_8')
ax.plot(random_ER_9,'#F0F8FF',label='Random_9')
ax.plot(random_ER_10,'#FFF8DC',label='Random_10')

plt.title('ER', fontsize = 10)


plt.xlabel('rewiring times',fontsize=12)
plt.ylabel('Second-order assortative coefficient',fontsize=10)




#pylab.legend(loc='upper right')
plt.savefig('trend_eeee.png')


plt.show()

# %%
random_ER_1 = pd.read_csv('ER/Random_ER_1.csv',header=None)
random_ER_2 = pd.read_csv('ER/Random_ER_2.csv',header=None)
random_ER_3 = pd.read_csv('ER/Random_ER_3.csv',header=None)
random_ER_4 = pd.read_csv('ER/Random_ER_4.csv',header=None)
random_ER_5 = pd.read_csv('ER/Random_ER_5.csv',header=None)
random_ER_6 = pd.read_csv('ER/Random_ER_6.csv',header=None)
random_ER_7 = pd.read_csv('ER/Random_ER_7.csv',header=None)
random_ER_8 = pd.read_csv('ER/Random_ER_8.csv',header=None)
random_ER_9 = pd.read_csv('ER/Random_ER_9.csv',header=None)
random_ER_10 = pd.read_csv('ER/Random_ER_10.csv',header=None)

# %%
fig = plt.figure(figsize=(5, 2))
ax = fig.add_subplot(111)
#ax.set_aspect(1)
ax.set_ylim(-0.2, 0.2)


ax.plot(random_ER_1,'b',label='Random_1')
ax.plot(random_ER_2,'c',label='Random_2')
ax.plot(random_ER_3,'g',label='Random_3')
ax.plot(random_ER_4,'k',label='Random_4')
ax.plot(random_ER_5,'m',label='Random_5')
ax.plot(random_ER_6,'r',label='Random_6')
ax.plot(random_ER_7,'w',label='Random_7')
ax.plot(random_ER_8,'y',label='Random_8')
ax.plot(random_ER_9,'#F0F8FF',label='Random_9')
ax.plot(random_ER_10,'#FFF8DC',label='Random_10')

plt.title('ER', fontsize = 10)


#pylab.legend(loc='upper right')
plt.savefig('trend_er.png')
#pylab.legend(loc='upper right')

plt.show()

# %%
random_protein_1 = pd.read_csv('protein/Random_protein_1.csv',header=None)
random_protein_2 = pd.read_csv('protein/Random_protein_2.csv',header=None)
random_protein_3 = pd.read_csv('protein/Random_protein_3.csv',header=None)
random_protein_4 = pd.read_csv('protein/Random_protein_4.csv',header=None)
random_protein_5 = pd.read_csv('protein/Random_protein_5.csv',header=None)
random_protein_6 = pd.read_csv('protein/Random_protein_6.csv',header=None)
random_protein_7 = pd.read_csv('protein/Random_protein_7.csv',header=None)
random_protein_8 = pd.read_csv('protein/Random_protein_8.csv',header=None)
random_protein_9 = pd.read_csv('protein/Random_protein_9.csv',header=None)
random_protein_10 = pd.read_csv('protein/Random_protein_10.csv',header=None)

# %%
random_protein_1 = random_protein_1[:100]
random_protein_2 = random_protein_2[:100]
random_protein_3 = random_protein_3[:100]
random_protein_4 = random_protein_4[:100]
random_protein_5 = random_protein_5[:100]
random_protein_6 = random_protein_6[:100]
random_protein_7 = random_protein_7[:100]
random_protein_8 = random_protein_8[:100]
random_protein_9 = random_protein_9[:100]
random_protein_10 = random_protein_10[:100]

# %%
fig = plt.figure(figsize=(10, 4))
ax = fig.add_subplot(111)
#ax.set_aspect(1)
ax.set_ylim(-0.3, 0.8)


ax.plot(random_protein_1,'b',label='Random_1')
ax.plot(random_protein_2,'c',label='Random_2')
ax.plot(random_protein_3,'g',label='Random_3')
ax.plot(random_protein_4,'k',label='Random_4')
ax.plot(random_protein_5,'m',label='Random_5')
ax.plot(random_protein_6,'r',label='Random_6')
ax.plot(random_protein_7,'w',label='Random_7')
ax.plot(random_protein_8,'y',label='Random_8')
ax.plot(random_protein_9,'#F0F8FF',label='Random_9')
ax.plot(random_protein_10,'#FFF8DC',label='Random_10')

ax.plot(random_internet_1,'b',label='Random_1')
ax.plot(random_internet_2,'c',label='Random_2')
ax.plot(random_internet_3,'g',label='Random_3')
ax.plot(random_internet_4,'k',label='Random_4')
ax.plot(random_internet_5,'m',label='Random_5')
ax.plot(random_internet_6,'r',label='Random_6')
ax.plot(random_internet_7,'w',label='Random_7')
ax.plot(random_internet_8,'y',label='Random_8')
ax.plot(random_internet_9,'#F0F8FF',label='Random_9')
ax.plot(random_internet_10,'#FFF8DC',label='Random_10')

ax.plot(random_scientist_1,'b',label='Random_1')
ax.plot(random_scientist_2,'c',label='Random_2')
ax.plot(random_scientist_3,'g',label='Random_3')
ax.plot(random_scientist_4,'k',label='Random_4')
ax.plot(random_scientist_5,'m',label='Random_5')
ax.plot(random_scientist_6,'r',label='Random_6')
ax.plot(random_scientist_7,'w',label='Random_7')
ax.plot(random_scientist_8,'y',label='Random_8')
ax.plot(random_scientist_9,'#F0F8FF',label='Random_9')
ax.plot(random_scientist_10,'#FFF8DC',label='Random_10')

plt.title('Internet, Protein, Scientist', fontsize = 10)
plt.xlabel('rewiring times',fontsize=10)
plt.ylabel('Second-order assortative coefficient',fontsize=10)

#pylab.legend(loc='upper right')
plt.savefig('trend_three.png')

#pylab.legend(loc='upper right')

plt.show()

# %%
random_scientist_1 = pd.read_csv('scientist/Random_scientist_1.csv',header=None)
random_scientist_2 = pd.read_csv('scientist/Random_scientist_2.csv',header=None)
random_scientist_3 = pd.read_csv('scientist/Random_scientist_3.csv',header=None)
random_scientist_4 = pd.read_csv('scientist/Random_scientist_4.csv',header=None)
random_scientist_5 = pd.read_csv('scientist/Random_scientist_5.csv',header=None)
random_scientist_6 = pd.read_csv('scientist/Random_scientist_6.csv',header=None)
random_scientist_7 = pd.read_csv('scientist/Random_scientist_7.csv',header=None)
random_scientist_8 = pd.read_csv('scientist/Random_scientist_8.csv',header=None)
random_scientist_9 = pd.read_csv('scientist/Random_scientist_9.csv',header=None)
random_scientist_10 = pd.read_csv('scientist/Random_scientist_10.csv',header=None)

# %%
random_scientist_1 = random_scientist_1[:100]
random_scientist_2 = random_scientist_2[:100]
random_scientist_3 = random_scientist_3[:100]
random_scientist_4 = random_scientist_4[:100]
random_scientist_5 = random_scientist_5[:100]
random_scientist_6 = random_scientist_6[:100]
random_scientist_7 = random_scientist_7[:100]
random_scientist_8 = random_scientist_8[:100]
random_scientist_9 = random_scientist_9[:100]
random_scientist_10 = random_scientist_10[:100]

# %%
fig = plt.figure(figsize=(5, 2))
ax = fig.add_subplot(111)
#ax.set_aspect(1)
ax.set_ylim(-0.1, 0.8)


ax.plot(random_scientist_1,'b',label='Random_1')
ax.plot(random_scientist_2,'c',label='Random_2')
ax.plot(random_scientist_3,'g',label='Random_3')
ax.plot(random_scientist_4,'k',label='Random_4')
ax.plot(random_scientist_5,'m',label='Random_5')
ax.plot(random_scientist_6,'r',label='Random_6')
ax.plot(random_scientist_7,'w',label='Random_7')
ax.plot(random_scientist_8,'y',label='Random_8')
ax.plot(random_scientist_9,'#F0F8FF',label='Random_9')
ax.plot(random_scientist_10,'#FFF8DC',label='Random_10')

plt.title('Scientist', fontsize = 10)


#pylab.legend(loc='upper right')
plt.savefig('trend_sci.png')
#pylab.legend(loc='upper right')

plt.show()

# %%
random_internet_1 = pd.read_csv('internet/Random_internet_1.csv',header=None)
random_internet_2 = pd.read_csv('internet/Random_internet_2.csv',header=None)
random_internet_3 = pd.read_csv('internet/Random_internet_3.csv',header=None)
random_internet_4 = pd.read_csv('internet/Random_internet_4.csv',header=None)
random_internet_5 = pd.read_csv('internet/Random_internet_5.csv',header=None)
random_internet_6 = pd.read_csv('internet/Random_internet_6.csv',header=None)
random_internet_7 = pd.read_csv('internet/Random_internet_7.csv',header=None)
random_internet_8 = pd.read_csv('internet/Random_internet_8.csv',header=None)
random_internet_9 = pd.read_csv('internet/Random_internet_9.csv',header=None)
random_internet_10 = pd.read_csv('internet/Random_internet_10.csv',header=None)

# %%
random_internet_1 = random_internet_1[:100]
random_internet_2 = random_internet_2[:100]
random_internet_3 = random_internet_3[:100]
random_internet_4 = random_internet_4[:100]
random_internet_5 = random_internet_5[:100]
random_internet_6 = random_internet_6[:100]
random_internet_7 = random_internet_7[:100]
random_internet_8 = random_internet_8[:100]
random_internet_9 = random_internet_9[:100]
random_internet_10 = random_internet_10[:100]

# %%
fig = plt.figure(figsize=(5, 2))
ax = fig.add_subplot(111)
#ax.set_aspect(1)
ax.set_ylim(-0.3, 0.2)


ax.plot(random_internet_1,'b',label='Random_1')
ax.plot(random_internet_2,'c',label='Random_2')
ax.plot(random_internet_3,'g',label='Random_3')
ax.plot(random_internet_4,'k',label='Random_4')
ax.plot(random_internet_5,'m',label='Random_5')
ax.plot(random_internet_6,'r',label='Random_6')
ax.plot(random_internet_7,'w',label='Random_7')
ax.plot(random_internet_8,'y',label='Random_8')
ax.plot(random_internet_9,'#F0F8FF',label='Random_9')
ax.plot(random_internet_10,'#FFF8DC',label='Random_10')

plt.title('Internet', fontsize = 10)


#pylab.legend(loc='upper right')
plt.savefig('trend_INTERNET.png')
#pylab.legend(loc='upper right')

plt.show()

# %%
fig = plt.figure(figsize=(5, 2))
ax = fig.add_subplot(111)
#ax.set_aspect(1)
ax.set_ylim(-0.1, 0.1)
ax.plot(random_BA_1,'b',label='Random_1')
ax.plot(random_BA_2,'c',label='Random_2')
ax.plot(random_BA_3,'g',label='Random_3')
ax.plot(random_BA_4,'k',label='Random_4')
ax.plot(random_BA_5,'m',label='Random_5')
ax.plot(random_BA_6,'r',label='Random_6')
ax.plot(random_BA_7,'w',label='Random_7')
ax.plot(random_BA_8,'y',label='Random_8')
ax.plot(random_BA_9,'#F0F8FF',label='Random_9')
ax.plot(random_BA_10,'#FFF8DC',label='Random_10')

bx = fig.add_subplot(111)
#ax.set_aspect(1)
#ax.set_ylim(-0.2, 0.2)


bx.plot(random_ER_1,'b',label='Random_1')
bx.plot(random_ER_2,'c',label='Random_2')
bx.plot(random_ER_3,'g',label='Random_3')
bx.plot(random_ER_4,'k',label='Random_4')
bx.plot(random_ER_5,'m',label='Random_5')
bx.plot(random_ER_6,'r',label='Random_6')
bx.plot(random_ER_7,'w',label='Random_7')
bx.plot(random_ER_8,'y',label='Random_8')
bx.plot(random_ER_9,'#F0F8FF',label='Random_9')
bx.plot(random_ER_10,'#FFF8DC',label='Random_10')
#pylab.legend(loc='upper right')

plt.show()
